# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.lineplot(x="species", y="petal_width", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
sns.relplot(
    data=iris,
    x='sepal_length',
    y='sepal_width',
    hue="species"
    
).set(
    title="Scatterplot",
    xlabel='Sepal Length',
    ylabel='Sepal Width')

# %%
sns.regplot(data=iris, x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.hist(iris)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1522         try:
# -> 1523             ret = self.converter.convert(x, self.units, self)
#    1524         except Exception as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-20-a66b1bfdb381> in <module>
# ...

# %%
sns.relplot(x="sepal_lenght", y="petal_lenght", col="region", hue="event", kind="line", data=iris)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-c2e9b6b1ee4a> in <module>
# ----> 1 sns.relplot(x="sepal_lenght", y="petal_lenght", col="region", hue="event", kind="line", data=iris)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     938
#     939     # Use the full dataset to map the semantics
# --> 940     p = plotter(
# ...

# %%
sns.relplot(x="sepal_width", y="species", col="region", hue="event", kind="line", data=fmri)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-7f3f049c034b> in <module>
# ----> 1 sns.relplot(x="sepal_width", y="species", col="region", hue="event", kind="line", data=fmri)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     938
#     939     # Use the full dataset to map the semantics
# --> 940     p = plotter(
# ...

# %%
plt.bar(sepal_width,sepal_length,color='gold',bottom=sepal_width)
plt.bar(petal_width,petal_length,color='green')
# Out:
# <BarContainer object of 150 artists>

# %%
sepal_width = iris['sepal_width']

# %%
sepal_length = iris['sepal_length']

# %%
petal_length = iris['petal_length']

# %%
petal_width = iris['sepal_width']

# %%
sns.relplot(x="sepal_width", y="species", kind="line", data=iris)

# %%
sns.relplot(x="sepal_length", y="species", kind="line", data=iris)
